# %%
import numpy as np
arr = np.array([1,2,3,4,5])
print(arr)
# Out:
# [1 2 3 4 5]

# %%
arr2 = np.array([[1,2,3],[4,5,6]])
print(arr2)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
ones = np.ones((2,3))
print(ones)
# Out:
# [[1. 1. 1.]
#  [1. 1. 1.]]

# %%
zeros = np.zeros((2,3))
print(zeros)
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]]

# %%
arr3 = np.arange(0,10,2)
print(arr3)
# Out:
# [0 2 4 6 8]

# %%
addarr = arr + arr3
print(addarr)
# Out:
# [ 1  4  7 10 13]

# %%
mean = np.mean(arr)
mean
# Out:
# 3.0

# %%
np.sum(arr)
# Out:
# 15

# %%
arr.T
# Out:
# array([1, 2, 3, 4, 5])

# %%
np.array([1,2,3,4,5,6]).reshape((3,2))
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
np.sort(arr)[::-1]
# Out:
# array([5, 4, 3, 2, 1])

# %%
arr[3]
# Out:
# 4

# %%
import numpy as np

def stepfn(z):
    return np.where(z >= 0, 1, 0)

steparr = np.array([1, 2, 3, 4, 5])  # Use parentheses here
ans = stepfn(steparr)
print(ans)
# Out:
# [1 1 1 1 1]

# %%
import numpy as np

def stepfn(z):
    return 1/(1+np.exp(-z))

sigmarr = np.array([1, -2, -3, 4, 5])  # Use parentheses here
ans = stepfn(sigmarr)
print(ans)
# Out:
# [0.73105858 0.11920292 0.04742587 0.98201379 0.99330715]

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load the Iris dataset
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
df = pd.read_csv(url, header=None, encoding='utf-8')

# Assign column names for clarity
df.columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']

# Plot sepal length vs sepal width
plt.figure(figsize=(10, 6))
# Use the named columns instead of numerical indices
plt.scatter(df['sepal_length'], df['sepal_width'], c=df['species'].astype('category').cat.codes, cmap='viridis', edgecolor='k')
plt.title('Sepal Length vs Sepal Width')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.colorbar(label='Species')
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Load the Iris dataset
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
df = pd.read_csv(url, header=None, encoding='utf-8')

# Prepare the target variable
#dataset has 150 flowers , first 50 are setosa, then versicolor and then virginica
y = df.iloc[0:100, 4].values # first 100 flowers are setosa and vergicolor
# y = np.where(y == 'Iris-setosa', 0, 1) 
#set setosas as 0 and versicolor as 1 
# Prepare the feature set
X = df.iloc[0:100, [0, 2]].values 

# Scatter plot for Iris-setosa
plt.scatter(X[:50, 0], X[:50, 1], color="red", marker='o', label='Iris-setosa')
# Scatter plot for Iris-versicolor
plt.scatter(X[50:100, 0], X[50:100, 1], color="black", marker='o', label='Iris-versicolor')

# Labeling the axes
plt.xlabel("Sepal Length")
plt.ylabel("Petal Length")
plt.legend()
plt.show()
